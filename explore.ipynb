# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image

# %%
# find current working directory using os module
os.getcwd()
# Out:
# '/Users/Tarek/Documents/masterRootAppFolder/EarlyDetection3DPrinterIssues'

# %%
DATA_PATH = '/Volumes/Photo SanDisk Pro/EarlyDetection3DPrinterIssues/early-detection-of-3d-printing-issues'
# reset path to data directory
os.chdir(DATA_PATH)

# %%
cwd = os.getcwd()
cwd
# Out:
# '/Volumes/Photo SanDisk Pro/EarlyDetection3DPrinterIssues/early-detection-of-3d-printing-issues'

# %%
# get a batch of images from the images folder
images_folders = sorted(os.listdir('./images'))
images_folders
# Out:
# ['021', '022', '023', '101', '102', '103', '104']

# %%
# get a batch of images from first image subfolder
image_subfolder_1 = sorted(os.listdir('./images/' + images_folders[0]))
image_subfolder_1
# Out:
# ['1673025450',
#  '1673031848',
#  '1673032842',
#  '1673034242',
#  '1673034918',
#  '1673037071',
#  '1673037348',
#  '1673037665',
#  '1673038169',
#  '1673040188',
#  '1673040671',
#  '1673041144',
#  '1673041994',
#  '1673043066',
#  '1673043367',
#  '1673043651',
#  '1673046546',
#  '1673047525',
#  '1673047933']

# %%
# list files of a directory
sample_image_files = os.listdir('./images/' + images_folders[0] + '/' + image_subfolder_1[0])
sample_image_files
# Out:
# ['1673025954.124256.jpg',
#  '1673025952.120417.jpg',
#  '1673026017.854936.jpg',
#  '1673025940.047641.jpg',
#  '1673026039.028117.jpg',
#  '1673026204.647247.jpg',
#  '1673026131.877873.jpg',
#  '1673025972.315804.jpg',
#  '1673025981.442639.jpg',
#  '1673026178.367848.jpg',
#  '1673026003.715385.jpg',
#  '1673026213.707092.jpg',
#  '1673026064.248674.jpg',
#  '1673026059.179111.jpg',
#  '1673026045.075879.jpg',
#  '1673026030.969212.jpg',
#  '1673026084.450441.jpg',
#  '1673026154.11933.jpg',
#  '1673026218.757532.jpg',
#  '1673026209.671285.jpg',
#  '1673026043.058464.jpg',
#  '1673026191.50474.jpg',
#  '1673026121.771862.jpg',
#  '1673026082.431505.jpg',
#  '1673026016.835182.jpg',
#  '1673026000.677915.jpg',
#  '1673026120.764231.jpg',
#  '1673026125.820457.jpg',
#  '1673026015.831314.jpg',
#  '1673026185.43623.jpg',
#  '1673026174.325592.jpg',
#  '1673026055.153555.jpg',
#  '1673025997.636991.jpg',
#  '1673025962.210086.jpg',
#  '1673026047.086402.jpg',
# ...

# %%
# render the first image of sample_image_files
sample_image = Image.open('./images/' + images_folders[0] + '/' + image_subfolder_1[0] + '/' + sample_image_files[0])

# %%
sample_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x720 at 0x7F96F99A0700>
